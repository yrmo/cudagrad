# %%
from os import system, environ

environ["PROFILING"] = "1"
for model in ["linear", "mlp"]:
    system(f"python -m cProfile -o ./profiles/{model}.prof -m cudagrad.{model}")
# Out:
# epoch=0 0.031350500881671906
# 0 OR 0 =  0.11 🔥
# 0 OR 1 =  0.65 🔥
# 1 OR 0 =  0.28
# 1 OR 1 =  0.82 🔥
# epoch=100 0.00902639888226986
# 0 OR 0 =  0.14 🔥
# 0 OR 1 =  0.7 🔥
# 1 OR 0 =  0.34
# 1 OR 1 =  0.91 🔥
# epoch=200 0.0008407398127019405
# 0 OR 0 =  0.16 🔥
# 0 OR 1 =  0.74 🔥
# 1 OR 0 =  0.39
# 1 OR 1 =  0.97 🔥
# epoch=300 0.0005816465709358454
# 0 OR 0 =  0.18 🔥
# 0 OR 1 =  0.77 🔥
# 1 OR 0 =  0.44
# 1 OR 1 =  1.02 🔥
# epoch=400 0.004469903651624918
# 0 OR 0 =  0.2 🔥
# 0 OR 1 =  0.79 🔥
# 1 OR 0 =  0.47
# 1 OR 1 =  1.07 🔥
# epoch=500 0.01025287713855505
# 0 OR 0 =  0.21 🔥
# 0 OR 1 =  0.81 🔥
# 1 OR 0 =  0.5 🔥
# 1 OR 1 =  1.1 🔥
# epoch=600 0.016627609729766846
# 0 OR 0 =  0.22 🔥
# 0 OR 1 =  0.82 🔥
# 1 OR 0 =  0.53 🔥
# 1 OR 1 =  1.13 🔥
# epoch=700 0.022875409573316574
# 0 OR 0 =  0.23 🔥
# 0 OR 1 =  0.83 🔥
# 1 OR 0 =  0.55 🔥
# 1 OR 1 =  1.15 🔥
# <frozen runpy>:128: RuntimeWarning: 'cudagrad.linear' found in sys.modules after import of package 'cudagrad', but prior to execution of 'cudagrad.linear'; this may result in unpredictable behaviour
# epoch=800 0.028630880638957024
# 0 OR 0 =  0.23 🔥
# 0 OR 1 =  0.84 🔥
# 1 OR 0 =  0.57 🔥
# 1 OR 1 =  1.17 🔥
# epoch=900 0.03373779356479645
# 0 OR 0 =  0.24 🔥
# 0 OR 1 =  0.84 🔥
# 1 OR 0 =  0.58 🔥
# 1 OR 1 =  1.18 🔥
# epoch=1000 0.03815963864326477
# 0 OR 0 =  0.24 🔥
# 0 OR 1 =  0.84 🔥
# 1 OR 0 =  0.6 🔥
# 1 OR 1 =  1.2 🔥
# epoch=0 0.31670036911964417
# 0 XOR 0 =  0.52
# 0 XOR 1 =  0.54 🔥
# 1 XOR 0 =  0.53 🔥
# 1 XOR 1 =  0.55
# <frozen runpy>:128: RuntimeWarning: 'cudagrad.mlp' found in sys.modules after import of package 'cudagrad', but prior to execution of 'cudagrad.mlp'; this may result in unpredictable behaviour
# epoch=500 0.2616712152957916
# 0 XOR 0 =  0.5 🔥
# 0 XOR 1 =  0.5 🔥
# 1 XOR 0 =  0.49
# 1 XOR 1 =  0.5 🔥
# epoch=1000 0.25707435607910156
# 0 XOR 0 =  0.5
# 0 XOR 1 =  0.51 🔥
# 1 XOR 0 =  0.49
# 1 XOR 1 =  0.5 🔥
# epoch=1500 0.2501971423625946
# 0 XOR 0 =  0.5
# 0 XOR 1 =  0.53 🔥
# 1 XOR 0 =  0.47
# 1 XOR 1 =  0.49 🔥
# epoch=2000 0.16110427677631378
# 0 XOR 0 =  0.42 🔥
# 0 XOR 1 =  0.76 🔥
# 1 XOR 0 =  0.37
# 1 XOR 1 =  0.4 🔥
# epoch=2500 0.046831753104925156
# 0 XOR 0 =  0.26 🔥
# 0 XOR 1 =  0.85 🔥
# 1 XOR 0 =  0.74 🔥
# 1 XOR 1 =  0.21 🔥
# epoch=3000 0.011328255757689476
# 0 XOR 0 =  0.12 🔥
# 0 XOR 1 =  0.91 🔥
# 1 XOR 0 =  0.89 🔥
# 1 XOR 1 =  0.11 🔥
# epoch=3500 0.005963664967566729
# 0 XOR 0 =  0.09 🔥
# 0 XOR 1 =  0.93 🔥
# 1 XOR 0 =  0.92 🔥
# 1 XOR 1 =  0.08 🔥
# epoch=4000 0.003968555014580488
# 0 XOR 0 =  0.07 🔥
# 0 XOR 1 =  0.94 🔥
# 1 XOR 0 =  0.94 🔥
# 1 XOR 1 =  0.06 🔥
# epoch=4500 0.0029490527231246233
# 0 XOR 0 =  0.06 🔥
# 0 XOR 1 =  0.95 🔥
# 1 XOR 0 =  0.95 🔥
# 1 XOR 1 =  0.05 🔥
# epoch=5000 0.0023360627237707376
# 0 XOR 0 =  0.05 🔥
# 0 XOR 1 =  0.96 🔥
# 1 XOR 0 =  0.95 🔥
# 1 XOR 1 =  0.05 🔥

# %%
import pstats


def profile(model: str) -> None:
    p = pstats.Stats(f"./profiles/{model}.prof")
    p.sort_stats("cumulative").print_stats(50)

# %%
profile("linear")
# Out:
# Sun Jan 28 10:28:10 2024    ./profiles/linear.prof
#
#          378924 function calls (378857 primitive calls) in 0.213 seconds
#
#    Ordered by: cumulative time
#    List reduced from 169 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       8/1    0.000    0.000    0.213    0.213 {built-in method builtins.exec}
#         1    0.000    0.000    0.213    0.213 <string>:1(<module>)
#         1    0.000    0.000    0.213    0.213 <frozen runpy>:201(run_module)
#         1    0.000    0.000    0.208    0.208 <frozen runpy>:65(_run_code)
#         1    0.019    0.019    0.208    0.208 /Users/ryan/cudagrad/cudagrad/linear.py:1(<module>)
#      4004    0.056    0.000    0.113    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:35(sgd)
#      8008    0.003    0.000    0.085    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:22(parameters)
#      8008    0.042    0.000    0.059    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:23(<listcomp>)
#      4004    0.003    0.000    0.047    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:29(zero_grad)
#      8008    0.022    0.000    0.022    0.000 {built-in method builtins.dir}
#    272345    0.017    0.000    0.017    0.000 {built-in method builtins.getattr}
#      4004    0.011    0.000    0.011    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:17(mse)
#     20020    0.006    0.000    0.010    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:36(positions)
#      4092    0.009    0.000    0.009    0.000 /Users/ryan/cudagrad/cudagrad/linear.py:22(__call__)
#      4004    0.008    0.000    0.008    0.000 {built-in method cudagrad.tensor.backward}
#         1    0.000    0.000    0.005    0.005 <frozen runpy>:105(_get_module_details)
#         1    0.000    0.000    0.005    0.005 {built-in method builtins.__import__}
#      11/1    0.000    0.000    0.005    0.005 <frozen importlib._bootstrap>:1167(_find_and_load)
#      11/1    0.000    0.000    0.005    0.005 <frozen importlib._bootstrap>:1122(_find_and_load_unlocked)
#      11/1    0.000    0.000    0.005    0.005 <frozen importlib._bootstrap>:666(_load_unlocked)
#       6/1    0.000    0.000    0.005    0.005 <frozen importlib._bootstrap_external>:934(exec_module)
#      27/2    0.000    0.000    0.005    0.002 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         1    0.000    0.000    0.005    0.005 /Users/ryan/cudagrad/cudagrad/__init__.py:1(<module>)
#     24134    0.004    0.000    0.004    0.000 {built-in method cudagrad.tensor.item}
#      8008    0.004    0.000    0.004    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:37(<listcomp>)
#        11    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap>:566(module_from_spec)
#         5    0.000    0.000    0.003    0.001 <frozen importlib._bootstrap_external>:1231(create_module)
#         5    0.003    0.001    0.003    0.001 {built-in method _imp.create_dynamic}
#      8008    0.002    0.000    0.002    0.000 {built-in method cudagrad.tensor.zero_grad}
#         1    0.000    0.000    0.002    0.002 /Users/ryan/cudagrad/cudagrad/nn.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 /Users/ryan/.pyenv/versions/3.11.1/lib/python3.11/random.py:1(<module>)
#         7    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1007(get_code)
#         7    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1127(get_data)
#        11    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1056(_find_spec)
#         7    0.001    0.000    0.001    0.000 {method 'read' of '_io.BufferedReader' objects}
#        11    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1496(find_spec)
#        11    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1464(_get_spec)
#        21    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1604(find_spec)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:727(_compile_bytecode)
#        55    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         7    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         1    0.000    0.000    0.000    0.000 /Users/ryan/.pyenv/versions/3.11.1/lib/python3.11/bisect.py:1(<module>)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#        44    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#         7    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#        93    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:392(cached)

# %%
profile("mlp")
# Out:
# Sun Jan 28 10:28:12 2024    ./profiles/mlp.prof
#
#          2523124 function calls (2523057 primitive calls) in 1.855 seconds
#
#    Ordered by: cumulative time
#    List reduced from 175 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       8/1    0.000    0.000    1.855    1.855 {built-in method builtins.exec}
#         1    0.000    0.000    1.855    1.855 <string>:1(<module>)
#         1    0.000    0.000    1.855    1.855 <frozen runpy>:201(run_module)
#         1    0.000    0.000    1.852    1.852 <frozen runpy>:65(_run_code)
#         1    0.120    0.120    1.852    1.852 /Users/ryan/cudagrad/cudagrad/mlp.py:1(<module>)
#     20004    0.797    0.000    1.195    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:35(sgd)
#     40008    0.016    0.000    0.458    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:22(parameters)
#     40008    0.230    0.000    0.325    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:23(<listcomp>)
#     20004    0.021    0.000    0.275    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:29(zero_grad)
#     40008    0.118    0.000    0.118    0.000 {built-in method builtins.dir}
#     20092    0.117    0.000    0.117    0.000 /Users/ryan/cudagrad/cudagrad/mlp.py:29(__call__)
#    260052    0.067    0.000    0.106    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:36(positions)
#   1520377    0.095    0.000    0.095    0.000 {built-in method builtins.getattr}
#     20004    0.091    0.000    0.091    0.000 {built-in method cudagrad.tensor.backward}
#    360182    0.064    0.000    0.064    0.000 {built-in method cudagrad.tensor.item}
#     20004    0.055    0.000    0.055    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:17(mse)
#     80016    0.039    0.000    0.039    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:37(<listcomp>)
#     80016    0.024    0.000    0.024    0.000 {built-in method cudagrad.tensor.zero_grad}
#         1    0.000    0.000    0.002    0.002 <frozen runpy>:105(_get_module_details)
#         1    0.000    0.000    0.002    0.002 {built-in method builtins.__import__}
#      11/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1167(_find_and_load)
#      11/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:1122(_find_and_load_unlocked)
#      11/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap>:666(_load_unlocked)
#       6/1    0.000    0.000    0.002    0.002 <frozen importlib._bootstrap_external>:934(exec_module)
#      27/2    0.000    0.000    0.002    0.001 <frozen importlib._bootstrap>:233(_call_with_frames_removed)
#         1    0.000    0.000    0.002    0.002 /Users/ryan/cudagrad/cudagrad/__init__.py:1(<module>)
#         1    0.000    0.000    0.002    0.002 /Users/ryan/cudagrad/cudagrad/linear.py:1(<module>)
#        11    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:566(module_from_spec)
#         1    0.000    0.000    0.001    0.001 /Users/ryan/.pyenv/versions/3.11.1/lib/python3.11/random.py:1(<module>)
#         5    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap_external>:1231(create_module)
#         5    0.001    0.000    0.001    0.000 {built-in method _imp.create_dynamic}
#        11    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:1056(_find_spec)
#         1    0.000    0.000    0.000    0.000 /Users/ryan/cudagrad/cudagrad/nn.py:1(<module>)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1007(get_code)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1496(find_spec)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1464(_get_spec)
#        55    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        21    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1604(find_spec)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:727(_compile_bytecode)
#         1    0.000    0.000    0.000    0.000 /Users/ryan/.pyenv/versions/3.11.1/lib/python3.11/bisect.py:1(<module>)
#         7    0.000    0.000    0.000    0.000 {built-in method marshal.loads}
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1127(get_data)
#        11    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:493(_init_module_attrs)
#        44    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:140(_path_stat)
#        93    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:126(_path_join)
#        44    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#         7    0.000    0.000    0.000    0.000 {built-in method io.open_code}
#        13    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:437(cache_from_source)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#        18    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:392(cached)
